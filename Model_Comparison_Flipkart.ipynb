# %%
import matplotlib.pyplot as plt

# Simulated epoch data
epochs = list(range(1, 11))  # 10 epochs for BERT
epochs_cnn_rnn = list(range(1, 6))  # 5 epochs for CNN and RNN


# BERT model data 
bert_training_accuracy = [0.9536, 0.9778, 0.9866, 0.9902, 0.9931, 0.9947, 0.9974, 0.9983, 0.9991, 0.9993]
bert_training_loss = [0.1659, 0.0840, 0.0534, 0.0387, 0.0279, 0.0234, 0.0116, 0.0067, 0.0032, 0.0032]

bert_validation_accuracy = [0.9755, 0.9815, 0.979, 0.9795, 0.9795, 0.978, 0.978, 0.977, 0.977, 0.9755]
bert_validation_loss = [0.0949, 0.0826, 0.0942, 0.0867, 0.1117, 0.1294, 0.1364, 0.1643, 0.1694, 0.1713]


# CNN model data 
cnn_training_accuracy = [0.9633, 0.9772, 0.9829, 0.9872, 0.9902]
cnn_training_loss = [0.1146, 0.0720, 0.0541, 0.0411, 0.0322]

cnn_validation_accuracy = [0.9718, 0.9742, 0.9734, 0.9726, 0.9723]
cnn_validation_loss = [0.0870, 0.0819, 0.0853, 0.0955, 0.1021]



# RNN model data 
rnn_training_accuracy = [0.9512, 0.9673, 0.9674, 0.9710, 0.9769]
rnn_training_loss = [0.1576, 0.1087, 0.1083, 0.0939, 0.0746]

rnn_validation_accuracy = [0.9652, 0.9253, 0.9674, 0.9682, 0.9682]
rnn_validation_loss = [0.1155, 0.2258, 0.1138, 0.1095, 0.1098]

# Create the figure for Training Metrics
plt.figure(figsize=(14, 6))
plt.suptitle('Model Comparison - Flipkart: Training Metrics', fontsize=16, y=1.02)

# Plotting Training Accuracy
plt.subplot(1, 2, 1)
plt.title("Training Accuracy over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Training Accuracy")
plt.plot(epochs, bert_training_accuracy, label='BERT')
plt.plot(epochs_cnn_rnn, cnn_training_accuracy, label='CNN')
plt.plot(epochs_cnn_rnn, rnn_training_accuracy, label='RNN')
plt.legend()

# Plotting Training Loss
plt.subplot(1, 2, 2)
plt.title("Training Loss over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Training Loss")
plt.plot(epochs, bert_training_loss, label='BERT')
plt.plot(epochs_cnn_rnn, cnn_training_loss, label='CNN')
plt.plot(epochs_cnn_rnn, rnn_training_loss, label='RNN')
plt.legend()

plt.tight_layout()
plt.show()

# Create the figure for Validation Metrics
plt.figure(figsize=(14, 6))
plt.suptitle('Model Comparison - Flipkart: Validation Metrics', fontsize=16, y=1.02)

# Plotting Validation Accuracy
plt.subplot(1, 2, 1)
plt.title("Validation Accuracy over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Validation Accuracy")
plt.plot(epochs, bert_validation_accuracy, label='BERT')
plt.plot(epochs_cnn_rnn, cnn_validation_accuracy, label='CNN')
plt.plot(epochs_cnn_rnn, rnn_validation_accuracy, label='RNN')
plt.legend()

# Plotting Validation Loss
plt.subplot(1, 2, 2)
plt.title("Validation Loss over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Validation Loss")
plt.plot(epochs, bert_validation_loss, label='BERT')
plt.plot(epochs_cnn_rnn, cnn_validation_loss, label='CNN')
plt.plot(epochs_cnn_rnn, rnn_validation_loss, label='RNN')
plt.legend()

plt.tight_layout()
plt.show()
