# %%
import matplotlib.pyplot as plt

# Simulated epoch data
epochs = list(range(1, 11))  # 10 epochs for BERT
epochs_cnn_rnn = list(range(1, 6))  # 5 epochs for CNN and RNN


# BERT model data 
bert_training_accuracy = [0.8546, 0.9364, 0.9673, 0.9833, 0.9894, 0.9937, 0.9963, 0.9977, 0.9990, 0.9990]
bert_training_loss = [0.4030, 0.2124, 0.1300, 0.0771, 0.0448, 0.0294, 0.0165, 0.0111, 0.0064, 0.0062]

bert_validation_accuracy = [0.8818, 0.9332, 0.9235, 0.9360, 0.9374, 0.9360, 0.9374, 0.9430, 0.9444, 0.9430]
bert_validation_loss = [0.3425, 0.2573, 0.3231, 0.3296, 0.3503, 0.4012, 0.4255, 0.4505, 0.4513, 0.4560]


# CNN model data 
cnn_training_accuracy = [0.7932, 0.9287, 0.9627, 0.9814, 0.9874]
cnn_training_loss = [0.5300, 0.2229, 0.1261, 0.0742, 0.0495]

cnn_validation_accuracy = [0.8857, 0.9154, 0.9246, 0.9295, 0.9287]
cnn_validation_loss = [0.3269, 0.2723, 0.2535, 0.2657, 0.2792]


# RNN model data 
rnn_training_accuracy = [0.7477, 0.9286, 0.9735, 0.9842, 0.9720]
rnn_training_loss = [0.6182, 0.2250, 0.0926, 0.0589, 0.0911]

rnn_validation_accuracy = [0.8468, 0.9064, 0.9078, 0.9119, 0.9026]
rnn_validation_loss = [0.4140, 0.2815, 0.3165, 0.3201, 0.3630]

# Create the figure for Training Metrics
plt.figure(figsize=(14, 6))
plt.suptitle('Model Comparison - Amazon: Training Metrics', fontsize=16, y=1.02)

# Plotting Training Accuracy
plt.subplot(1, 2, 1)
plt.title("Training Accuracy over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Training Accuracy")
plt.plot(epochs, bert_training_accuracy, label='BERT')
plt.plot(epochs_cnn_rnn, cnn_training_accuracy, label='CNN')
plt.plot(epochs_cnn_rnn, rnn_training_accuracy, label='RNN')
plt.legend()

# Plotting Training Loss
plt.subplot(1, 2, 2)
plt.title("Training Loss over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Training Loss")
plt.plot(epochs, bert_training_loss, label='BERT')
plt.plot(epochs_cnn_rnn, cnn_training_loss, label='CNN')
plt.plot(epochs_cnn_rnn, rnn_training_loss, label='RNN')
plt.legend()

plt.tight_layout()
plt.show()

# Create the figure for Validation Metrics
plt.figure(figsize=(14, 6))
plt.suptitle('Model Comparison - Amazon: Validation Metrics', fontsize=16, y=1.02)

# Plotting Validation Accuracy
plt.subplot(1, 2, 1)
plt.title("Validation Accuracy over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Validation Accuracy")
plt.plot(epochs, bert_validation_accuracy, label='BERT')
plt.plot(epochs_cnn_rnn, cnn_validation_accuracy, label='CNN')
plt.plot(epochs_cnn_rnn, rnn_validation_accuracy, label='RNN')
plt.legend()

# Plotting Validation Loss
plt.subplot(1, 2, 2)
plt.title("Validation Loss over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Validation Loss")
plt.plot(epochs, bert_validation_loss, label='BERT')
plt.plot(epochs_cnn_rnn, cnn_validation_loss, label='CNN')
plt.plot(epochs_cnn_rnn, rnn_validation_loss, label='RNN')
plt.legend()

plt.tight_layout()
plt.show()
