# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd


# Load the CSV data
data = pd.read_csv('/content/drive/MyDrive/flipkart_processed_output.csv')

# Filter positive and negative reviews
positive_reviews = data[data["Output"] == "Positive"][["Review", "Summary"]]
negative_reviews = data[data["Output"] == "Negative"][["Review", "Summary"]]

# Check lengths of filtered reviews
print("Positive Reviews:", len(positive_reviews))
print("Negative Reviews:", len(negative_reviews))

# Combine the "Review" and "Summary" columns
positive_combined = positive_reviews["Review"].str.cat(positive_reviews["Summary"], sep=' ', na_rep='')
negative_combined = negative_reviews["Review"].str.cat(negative_reviews["Summary"], sep=' ', na_rep='')

# Check a few rows of combined text
print("Positive Combined Text:\n", positive_combined.head())
print("Negative Combined Text:\n", negative_combined.head())

# Generate word clouds for positive and negative combined text
wordcloud_positive = WordCloud(width=800, height=400, background_color="white").generate(" ".join(positive_combined))
wordcloud_negative = WordCloud(width=800, height=400, background_color="white").generate(" ".join(negative_combined))

# Plot word clouds
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_positive, interpolation="bilinear")
plt.title("Word Cloud for Positive Reviews")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(wordcloud_negative, interpolation="bilinear")
plt.title("Word Cloud for Negative Reviews")
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Positive Reviews: 145136
# Negative Reviews: 20017
# Positive Combined Text:
#  0    super Great cooler excellent air flow and for ...
# 1        awesome Best budget 2 fit cooler Nice cooling
# 2    fair The quality is good but the power of air ...
# 4                                   fair Ok ok product
# 5    awesome The cooler is really fantastic and pro...
# Name: Review, dtype: object
# Negative Combined Text:
#  3     useless product Very bad product its a only a fan
# 8                        unsatisfactory Very bad cooler
# 32                expected a better product Bad quality
# 48    waste of money Small wire and moter capacity i...
# 59    worthless The product doesnt cool as rated by ...
# Name: Review, dtype: object
